# %%
"""Importaion of the all the important imports for the performance of the task """

import numpy as np
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

algo =LinearRegression()

""" Import the Data file """
data = np.loadtxt('FuelEconomy.csv',delimiter =',')

x = data[:,0].reshape(-1,1)
y = data[:,1]

# x.shape (Find the shape of the X)
# y.shape (Find the shape of the Y)

x_train,x_test,y_train,y_test =model_selection.train_test_split(x,y,test_size=0.30,random_state=42)
algo.fit(x_train,y_train)

m=round(algo.coef_[0],2)
c=round(algo.intercept_,2)

x_line = np.arange(0,350,10).reshape(-1,1)
y_line = algo.predict(x_line)

# Plotting the regression line and scatter plot
plt.scatter(x_test, y_test, color='blue', label='Test Data') 
plt.plot(x_line, y_line, color='red', linestyle='dashed', label='Regression Line') 
plt.xlabel("Feature (X)")  # Label for x-axis
plt.ylabel("Target (Y)")  # Label for y-axis
plt.title("Linear Regression Model") 
plt.legend()
plt.show()

# %% [markdown]
# #### Here we will find the Round figure of the coef and intercept of the Fuel Economy

# %%
"""Importaion of the all the important imports for the performance of the task """

import numpy as np
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

algo =LinearRegression()

""" Import the Data file """
data = np.loadtxt('FuelEconomy.csv',delimiter =',')

x = data[:,0].reshape(-1,1)
y = data[:,1]

# x.shape (Find the shape of the X)
# y.shape (Find the shape of the Y)

x_train,x_test,y_train,y_test =model_selection.train_test_split(x,y,test_size=0.30,random_state=42)
algo.fit(x_train,y_train)

m=round(algo.coef_[0],2)
c=round(algo.intercept_,2)

print(m)
print(c)
# Out:
# -0.07
# 38.84

# %% [markdown]
# #### Here we wil find the score of the testing and Training of the Fuel Economy

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Load dataset
data = np.loadtxt('FuelEconomy.csv', delimiter=',')

# Split features (X) and target (Y)
x = data[:, 0].reshape(-1, 1)  # Reshape to 2D
y = data[:, 1]

# Split dataset (70% train, 30% test) with random_state=42
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42)

# Create and train Linear Regression model
model = LinearRegression()
model.fit(x_train, y_train)

# Calculate training and testing scores
train_score = round(model.score(x_train, y_train), 3)  # Training score
test_score = round(model.score(x_test, y_test), 3)  # Testing score

# Print the training and testing scores
print(train_score)
print(test_score)
# Out:
# 0.906
# 0.913
