# %% [markdown]
# #### Code to Perform the Addition of new independent feature in the Datase.csv file to get the score values of them

# %% [markdown]
# #### 1. Importation of the all the necessary lib. for the task to be completed and well perfromed

# %%
"Library to import "
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

"Loading the numpy values"
data_values_1 = np.loadtxt('datase.csv',delimiter=',')
x = data_values_1.data
y = data_values_1

x.shape
y.shape

"Loading of new CSV file for the task "
df = pd.read_csv("datase.csv")

"""Convert to the Data Frame"""
dt=pd.DataFrame(df)
print( dt.columns)

x=dt.values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: could not convert string to float: 'CRIM'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 8
#       5 from sklearn.linear_model import LinearRegression
#       7 "Loading the numpy values"
# ----> 8 data_values_1 = np.loadtxt('datase.csv',delimiter=',')
#       9 x = data_values_1.data
#      10 y = data_values_1.target
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\lib\_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
#    1395     delimiter = delimiter.decode('latin1')
# ...

# %%
if 'AGE' in df.columns and 'RM' in df.columns:
    df['Age_2'] = df['AGE'] ** 2
    df['RM_2'] = df['RM'] ** 2
else:
    print("Columns 'AGE' and/or 'RM' not found in the dataset.")
  
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...
